# %%
import numpy as np
import pandas as pd
import pyuvm

print(f"NumPy: {np.__version__}")
print(f"Pandas: {pd.__version__}")
print(f"pyuvm: {pyuvm.__version__}")
# Out:
# NumPy: 2.4.2
# Pandas: 3.0.0
# pyuvm: 4.0.1
